# %%
from supplychain_lots.core import LotProblem

# Test avec les données originales
A = [[500, 300, 800], [1000, 2000, 1500], [10, 20, 15], [100, 80, 15], [80, 120, 200]]
b = [100000, 200000, 100, 400, 400]
c = [10, 12, 15]

problem = LotProblem(A, b, c, name="Patibulaire")
print(problem.get_solution_summary())
